# %% [markdown]
# # Homework 3 and 4 due November December 21$^{st}$, 2021
#
# The aim of this homework is to practice the concepts of objects and numpy module in Python. You are expected to use GitHub Classroom and present your work as an html file (i.e. web page) on your progress journals. You can use this jupyter notebook as template to provide your answers.
#
#
# ## Object-oriented programming concepts
# Tasks 1-6 require the definition of objects with init and sample uses to check if classes is defined as intented.

# %% [markdown]
# ### Task 1
# Implement a Python program to create a course class with the course code, course name, credit information. Use this class to create a course object for FE588 and print instance attributes. Also check which class a given course object belongs to.
#
# Hint: A sample template to create an object from this class can be as the following:
#
# my_course=course('FE588', 'Python Programming for Financial Engineering')

# %%
class Course:
    def __init__(self,code,name,credit_information):
        self.code=code
        self.name=name
        self.credit_information=credit_information
my_course=Course('FE588', 'Python Programming for Financial Engineering',3)

print("Course Class: " + type(my_course).__name__)
print("Course Code:" + my_course.code)
print("Course Name:" + my_course.name)
print("Credit Information:" + str(my_course.credit_information))
# Out:
# Course Class: Course
# Course Code:FE588
# Course Name:Python Programming for Financial Engineering
# Credit Information:3

# %% [markdown]
# ### Task 2
# This part requires to create a student object with the name, id and grade attributes. You can assume name is string, id is an integer variable and grade is a list that can store multiple grades.
#
# Hint: A sample template to create an object from this class can be as the following:
#
# mustafa=student('Mustafa', 123, grades=None)
# or
# mustafa=student('Mustafa', 123, grades=[85, 70, 100])

# %%
class Student:
    def __init__(self,name,id,grades):
        self.name=name
        self.id=id
        self.grades=grades
mustafa=Student('Mustafa', 123, grades=None)  
ahmet=Student('Ahmet', 123, grades=[85, 70, 100]) 
students=[mustafa,ahmet]
for student in students:
    print("Course Class: " + type(student).__name__)
    print("Course Code:" + student.name)
    print("Course Name:" + str(student.id))
    print("Grades:" + str(student.grades))
    print("**************************")
# Out:
# Course Class: Student
# Course Code:Mustafa
# Course Name:123
# Grades:None
# **************************
# Course Class: Student
# Course Code:Ahmet
# Course Name:123
# Grades:[85, 70, 100]
# **************************

# %% [markdown]
# ### Task 3
# Let's modify the course class so that it can store the information of students as a list of student objects.
#
# Hint: A sample template to create an object from this class can be as the following:
#
# mustafa=student('Mustafa', 123, grades=None)
# ahmet=student('Ahmet', 124, grades=[90, 95, 87])
# my_course=course('FE588', 'Python Programming for Financial Engineering', students=[mustafa, ahmet])

# %%
class Course:
    def __init__(self,code,name,students,credit_information=3):
        self.code=code
        self.name=name
        self.credit_information=credit_information
        self.students=students
        

my_course=Course('FE588', 'Python Programming for Financial Engineering', students=[mustafa, ahmet])

print("Course Class: " + type(my_course).__name__)
print("Course Code:" + my_course.code)
print("Course Name:" + my_course.name)
print("Credit Information:" + str(my_course.credit_information))

for student in my_course.students:
    print("***********")
    print("Course Class: " + type(student).__name__)
    print("Course Code:" + student.name)
    print("Course Name:" + str(student.id))
    print("Grades:" + str(student.grades))
# Out:
# Course Class: Course
# Course Code:FE588
# Course Name:Python Programming for Financial Engineering
# Credit Information:3
# ***********
# Course Class: Student
# Course Code:Mustafa
# Course Name:123
# Grades:None
# ***********
# Course Class: Student
# Course Code:Ahmet
# Course Name:123
# Grades:[85, 70, 100]

# %% [markdown]
# ### Task 4
# Implement a method for course object so that you can append new students to the roster.

# %%
class Course:
    
    def __init__(self,code,name,students=[mustafa, ahmet],credit_information=3):
        self.code=code
        self.name=name
        self.credit_information=credit_information
        self.students=students
        
    def addStudent(self,newstudent):
        self.students.append(newstudent)

my_course=Course('FE588', 'Python Programming for Financial Engineering', students=[mustafa, ahmet])

        
veli=Student('Veli', 125, grades=[12, 100])
my_course.addStudent(newstudent=veli)

print("Course Class: " + type(my_course).__name__)
print("Course Code:" + my_course.code)
print("Course Name:" + my_course.name)
print("Credit Information:" + str(my_course.credit_information))

for student in my_course.students:
    print("***********")
    print("Course Class: " + type(student).__name__)
    print("Course Code:" + student.name)
    print("Course Name:" + str(student.id))
    print("Grades:" + str(student.grades))
# Out:
# Course Class: Course
# Course Code:FE588
# Course Name:Python Programming for Financial Engineering
# Credit Information:3
# ***********
# Course Class: Student
# Course Code:Mustafa
# Course Name:123
# Grades:None
# ***********
# Course Class: Student
# Course Code:Ahmet
# Course Name:123
# Grades:[85, 70, 100]
# ***********
# Course Class: Student
# Course Code:Veli
# Course Name:125
# Grades:[12, 100]

# %% [markdown]
# ### Task 5
# Implement a method for course object that you can calculate the average of the grades for each student. Print the averages for the students you have created in Task 3.

# %%
class Course:
    
    def __init__(self,code,name,students=[mustafa, ahmet],credit_information=3):
        self.code=code
        self.name=name
        self.credit_information=credit_information
        self.students=students
        
    def addStudent(self,newstudent):
        self.students.append(newstudent)
    
    def avgGrade(self,Student):
        if type(Student.grades)==list:
            
            return sum(Student.grades)/len(Student.grades)
        else:
            return " couldn't calculate"
        
        

my_course=Course('FE588', 'Python Programming for Financial Engineering', students=[mustafa, ahmet])

print("Ahmet Avg Grade : "+ str(my_course.avgGrade(ahmet)))
print("Mustafa Avg Grade : "+ str(my_course.avgGrade(mustafa)))
print("Veli Avg Grade : "+ str(my_course.avgGrade(veli)))
# Out:
# Ahmet Avg Grade : 85.0
# Mustafa Avg Grade :  couldn't calculate
# Veli Avg Grade : 56.0

# %% [markdown]
# ### Task 6
# Implement a method for course object that you can find the student with maximum average grade and print the student's name and average grade.

# %%
class Course:
    
    def __init__(self,code,name,students=[mustafa, ahmet],credit_information=3):
        self.code=code
        self.name=name
        self.credit_information=credit_information
        self.students=students
        
    def addStudent(self,newstudent):
        self.students.append(newstudent)
    
    def avgGrade(self,Student):
        if type(Student.grades)==list:
            
            return sum(Student.grades)/len(Student.grades)
        else:
            return " couldn't calculate"
    
    def maxGrade(self):
        grades={}
        for i in self.students:
            if type(i.grades)==list:
                grades[i.name]= sum(i.grades)/len(i.grades)
            else:
                pass
        return max(grades,key=grades.get),max(grades.values())
        
        

my_course=Course('FE588', 'Python Programming for Financial Engineering', students=[mustafa, ahmet])

print("{} has maximum Avg Grade with {} point".format(my_course.maxGrade()[0],my_course.maxGrade()[1]))
# Out:
# Ahmet has maximum Avg Grade with 85.0 point

# %% [markdown]
# ## Matrix manipulation on images
# In this exercise, you are requested to perform certain operations on images. The aim is to develop matrix manipulation skills.
#
# Here is a background information about how a grayscale image is represented on our computers. A grayscale image is basically a matrix where each matrix entry shows the intensity (brightness) level. In other words, when you take a picture with a digital camera, the image is represented by a numerical matrix where the matrix size is defined by the resolution setting of your camera. If your resolution setting is 1280x720, then your image is represented by 1280x720= 921600 pixel values (Actually that is why higher resolution provides better quality pictures). When you have a color image, the image stores the information of multiple channels depending on the image type. The most famous one is RGB type where R, G and B stand for “red”, “green” and “blue” respectively. Hence, you have a matrix as in greyscale images representing the intensity for each channel. Combining these matrices generates the color image.
#
# Below is the steps you need to follow for this task:
# - Take a picture of yours and save it as *.jpg or *.jpeg file.
# - Using an image editor (i.e. Paint in Windows), crop your head from the image and save it as separate image file (again *.jpg or *.jpeg). The resulting image is expected to be a square (i.e. has the same length and width), hence you should crop the image accordingly.
# - Resize the cropped image to size 512x512 px (pixel) using an image editor. This image is the one that you will use for this exercise.

# %% [markdown]
# ### Task 7
# Read image as numpy array in Python. You can use matplotlib module. If your environment does not have this module, please install using 'pip install matplotlib'. You can use 'asarray' function from numpy to transform your image contents to numpy array.
#
# What is the structure of the variable that stores the image? What is the dimension? Display the image.
#
# Hint: You can use the following set of scripts to read the image.
# from matplotlib import image
# from matplotlib import pyplot
# from numpy import asarray
#
# image = image.imread('your_image.jpg')
# data = asarray(image)

# %%
from matplotlib import image
import matplotlib.pyplot as plt
import numpy as np
from numpy import asarray

image = image.imread('ozan.jpg')
data = asarray(image)

# %%
print("image store as : {}".format(type(data)))
print("array shape is : {}".format(data.shape))
# Out:
# image store as : <class 'numpy.ndarray'>
# array shape is : (512, 512, 3)

# %%
plt.imshow(image)

# %% [markdown]
# ### Task 8
# Display each channel as separate image

# %%
R=image[:,:,0]
plt.imshow(R)

# %%
G=image[:,:,1]
plt.imshow(G)

# %%
B=image[:,:,2]
plt.imshow(B)

# %% [markdown]
# ### Task 9
# For each channel, calculate the average, maximum and minimum of the columns and store it in three variables using numpy methods defined for numpy objects. What is the structure of the variables storing the average, max and min information.

# %%
R_max_min_avg=np.empty(shape=(512,3),dtype='object')
for i in range(len(R[0])):
    R_max_min_avg[i,0]=np.max(R[:,i])
    R_max_min_avg[i,1]=np.min(R[:,i])
    R_max_min_avg[i,2]=np.mean(R[:,i])

# %%
print("R max_min_avg shape {}".format(R_max_min_avg.shape))
R_max_min_avg
# Out:
# R max_min_avg shape (512, 3)
# array([[171, 55, 132.314453125],
#        [169, 57, 132.11328125],
#        [169, 55, 131.826171875],
#        ...,
#        [187, 75, 167.634765625],
#        [189, 77, 167.99609375],
#        [188, 75, 167.810546875]], dtype=object)

# %%
G_max_min_avg=np.empty(shape=(512,3),dtype='object')
for i in range(len(G[0])):
    G_max_min_avg[i,0]=np.max(G[:,i])
    G_max_min_avg[i,1]=np.min(G[:,i])
    G_max_min_avg[i,2]=np.mean(G[:,i])
print("G max_min_avg shape {}".format(G_max_min_avg.shape))
G_max_min_avg
# Out:
# G max_min_avg shape (512, 3)
# array([[176, 16, 125.640625],
#        [174, 16, 125.4296875],
#        [174, 16, 125.140625],
#        ...,
#        [199, 22, 165.416015625],
#        [200, 23, 165.625],
#        [198, 21, 165.36328125]], dtype=object)

# %%
B_max_min_avg=np.empty(shape=(512,3),dtype='object')
for i in range(len(B[0])):
    B_max_min_avg[i,0]=np.max(B[:,i])
    B_max_min_avg[i,1]=np.min(B[:,i])
    B_max_min_avg[i,2]=np.mean(B[:,i])
print("B max_min_avg shape {}".format(B_max_min_avg.shape))
B_max_min_avg
# Out:
# B max_min_avg shape (512, 3)
# array([[163, 9, 115.466796875],
#        [161, 10, 115.26171875],
#        [161, 10, 114.9765625],
#        ...,
#        [196, 18, 163.85546875],
#        [196, 18, 164.150390625],
#        [196, 16, 163.923828125]], dtype=object)

# %%
fig, (ax1,ax2) = plt.subplots(2, 1,gridspec_kw={'height_ratios': [4, 1]},figsize=(7,10))
ax1.imshow(image)
ax2.plot(R_max_min_avg[:,2],label="R")
ax2.plot(G_max_min_avg[:,2],label="G")
ax2.plot(B_max_min_avg[:,2],label="B")
plt.legend
plt.show()

# %% [markdown]
# ### Task 10
# For each channel, subtract one half of the image from the other half (choice of halves is up to you
# but dividing the head image vertically into two parts make more sense). If you observe negative pixel
# values, you can make them equal to zero. Then:
# - Display the new image.
# - Display each channel separately as separate image.

# %%
plt.imshow(image[:,:256])
plt.show()

# %%
plt.imshow(image[:,256:])
plt.show()

# %%
contrast_image=image[:,256:]-image[:,:256]
plt.imshow(contrast_image)

# %%
plt.imshow(contrast_image[:,:,0])

# %%
plt.imshow(contrast_image[:,:,1])

# %%
plt.imshow(contrast_image[:,:,2])

# %% [markdown]
# ### Tasks 11-12
#
# In order to create a noisy image, add a random noise from normal distribution for alternative mean and standard deviation settings to each pixel value for each channel of original image. You can try $\mu \in \{5,10\}$ and $\sigma \in \{1,2\}$. So two types of noise are expected: mean=2 and st. dev=1, mean=10 and st.dev=2.
# - Display the new image.
# - Display each channel separately as separate image.

# %%
random_int_number_1=np.empty(image.shape)
random_int_number_10=np.empty(image.shape)

random_normal_float_1=np.random.normal(2,1,image.shape)
random_normal_float_10=np.random.normal(10,2,image.shape)

new_image=np.empty(image.shape)
for i in range(random_int_number.shape[0]):
    for a in range(random_int_number.shape[1]):
        random_int_number_1[i,a]=np.array([x/255 for x in random_normal_float_1[i,a]])
        random_int_number_10[i,a]=np.array([x/255 for x in random_normal_float_10[i,a]])

        new_image[i,a]=np.array([x/255 for x in image[i,a]])
new_image=random_int_number_1+random_int_number_10+new_image
print("adding random noise image")
plt.imshow(new_image)
plt.show()
print("orginal image")

plt.imshow(image)
plt.show()
# Out:
# adding random noise image
# orginal image

# %%
print("adding random noise image")
R_new=new_image[:,:,0]
plt.imshow(R_new)
plt.show()
print("orginal image")
plt.imshow(R)
plt.show()
# Out:
# adding random noise image
# orginal image

# %%
print("adding random noise image")
B_new=new_image[:,:,1]
plt.imshow(B_new)
plt.show()
print("orginal image")
plt.imshow(B)
plt.show()
# Out:
# adding random noise image
# orginal image

# %%
print("adding random noise image")
G_new=new_image[:,:,2]
plt.imshow(G_new)
plt.show()
print("orginal image")
plt.imshow(G)
plt.show()
# Out:
# adding random noise image
# orginal image

# %% [markdown]
# # Adding large random number with big std for fun

# %%
random_int_number_1=np.empty(image.shape)
random_int_number_10=np.empty(image.shape)

random_normal_float_1=np.random.normal(25,10,image.shape)
random_normal_float_10=np.random.normal(100,50,image.shape)

new_image=np.empty(image.shape)
for i in range(random_int_number.shape[0]):
    for a in range(random_int_number.shape[1]):
        random_int_number_1[i,a]=np.array([x/255 for x in random_normal_float_1[i,a]])
        random_int_number_10[i,a]=np.array([x/255 for x in random_normal_float_10[i,a]])

        new_image[i,a]=np.array([x/255 for x in image[i,a]])
new_image=random_int_number_1+random_int_number_10+new_image
print("adding random noise image")
plt.imshow(new_image)
plt.show()
print("orginal image")

plt.imshow(image)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# adding random noise image
# orginal image

# %%
print("adding random noise image")
R_new=new_image[:,:,0]
plt.imshow(R_new)
plt.show()
print("orginal image")
plt.imshow(R)
plt.show()
# Out:
# adding random noise image
# orginal image

# %%
print("adding random noise image")
B_new=new_image[:,:,1]
plt.imshow(B_new)
plt.show()
print("orginal image")
plt.imshow(B)
plt.show()
# Out:
# adding random noise image
# orginal image

# %%
print("adding random noise image")
G_new=new_image[:,:,2]
plt.imshow(G_new)
plt.show()
print("orginal image")
plt.imshow(G)
plt.show()
# Out:
# adding random noise image
# orginal image
